# %%
import numpy as np
import pandas as pd

# %%
panda_read = pd.read_csv('pandas_tutorial_read.csv', delimiter = ';', names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])
blog_read = pd.read_csv('pandas_tutorial_buy.csv', delimiter = ';', names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

# %%
panda_merge = panda_read.merge(blog_read, how = 'left', left_on = 'user_id', right_on = 'user_id')

# %%
blog_read.fillna(0)
# Out:
#             my_datetime event     country  user_id  source  topic
# 0   2018-01-01 04:04:59   buy  2458151555        8     0.0    0.0
# 1   2018-01-01 09:28:00   buy  2458151933        8     0.0    0.0
# 2   2018-01-01 13:23:16   buy  2458152245        8     0.0    0.0
# 3   2018-01-01 14:20:43   buy  2458152315      100     0.0    0.0
# 4   2018-01-02 02:57:43   buy  2458153264        8     0.0    0.0
# 5   2018-01-02 05:25:38   buy  2458152579      100     0.0    0.0
# 6   2018-01-02 06:56:41   buy  2458152825      800     0.0    0.0
# 7   2018-01-02 07:57:24   buy  2458151525       80     0.0    0.0
# 8   2018-01-02 12:47:33   buy  2458151771        8     0.0    0.0
# 9   2018-01-02 18:09:20   buy  2458151468       88     0.0    0.0
# 10  2018-01-02 19:14:09   buy  2458151757        8     0.0    0.0
# 11  2018-01-02 23:01:53   buy  2458151919        8     0.0    0.0
# 12  2018-01-03 01:33:30   buy  2458151481      200     0.0    0.0
# ...

# %%
dd = pd.DataFrame()
